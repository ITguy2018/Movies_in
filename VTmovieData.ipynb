# %%
import pandas as pd

# %%
movies = pd.read_csv('VTmoviesCoords.csv')

# %%
movies.head(15)
# Out:
#                     Title  Year           Town  \
# 0               Star Trek  2009          Barre
# 1            Forrest Gump  1993        Reading
# 2            Beetle Juice  1988   East Cornith
# 3               Baby Boom  1987           Peru
# 4        The Four Seasons  1981          Stowe
# 5              Funny Farm  1988      Townshend
# 6      Me, Myself & Irene  2000      Waterbury
# 7             Ethan Frome  1993        Peachem
# 8      The Spitfire Grill  1996        Peachem
# 9   The Cider House Rules  1999  Bellows Falls
# 10      What Lies Beneath  1999   West Addison
# 11     Sweet Hearts Dance  1988      Hyde Park
# 12                   Wolf  1994     Buels Gore
#
#                                               Address  \
# 0         560 Graniteville Rd, Graniteville, VT 05654
# 1              1279-1163, Jenne Rd, Reading, VT 05062
# 2           1 Chicken Farm Rd, East Corinth, VT 05040
# 3                     Baby Boom House, Peru, VT 05152
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   13 non-null     object
#  1   Year                    13 non-null     int64
#  2   Town                    13 non-null     object
#  3   Address                 13 non-null     object
#  4   Description             13 non-null     object
#  5   Latitude                13 non-null     float64
#  6   Longitude               13 non-null     float64
#  7   URL                     13 non-null     object
#  8   Starring                13 non-null     object
#  9   Box Office Gross        13 non-null     object
#  10  Adjusted for Inflation  13 non-null     object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 1.2+ KB
